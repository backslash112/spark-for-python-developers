# %%
from TwitterAPI import TwitterAPI
twitterAPI = TwitterAPI()

# %%
twitterAPI.getTweets('Spark')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-18e3bbfe5a55> in <module>()
# ----> 1 twitterAPI.getTweets('Spark')
#
# /home/carl/Workspace/spark-for-python-developers/chapter3-juggling-data/TwitterAPI.pyc in getTweets(self, q, max_res)
#     148         while True:
#     149             try:
# --> 150                 self.searchTwitter(q, max_res=1000)
#     151             except twitter.api.TwitterHTTPError as e:
#     152                 error_count = 0
#
# /home/carl/Workspace/spark-for-python-developers/chapter3-juggling-data/TwitterAPI.pyc in searchTwitter(self, q, max_res, **kwargs)
#      86             kwargs = dict(next_results)
#      87             self.logger.info('++++++++++++++++++++++ api.search.tweets(for: %i) %s ' % (i, kwargs))
# ---> 88             search_results = self.api.search.tweets(**kwargs)
# ...

# %%
twitterAPI.getTweets('Python')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-02f8d1ef1d8e> in <module>()
# ----> 1 twitterAPI.getTweets('Python')
#
# /home/carl/Workspace/spark-for-python-developers/chapter3-juggling-data/TwitterAPI.py in getTweets(self, q, max_res)
#     148         while True:
#     149             try:
# --> 150                 self.searchTwitter(q, max_res=1000)
#     151             except twitter.api.TwitterHTTPError as e:
#     152                 error_count = 0
#
# /home/carl/Workspace/spark-for-python-developers/chapter3-juggling-data/TwitterAPI.py in searchTwitter(self, q, max_res, **kwargs)
#      71     def searchTwitter(self, q, max_res=1000, **kwargs):
#      72         self.logger.info('++++++++++++++++++++++ api.search.tweets %s ' % kwargs)
# ---> 73         search_results = self.api.search.tweets(q=q, count=10, **kwargs)
# ...

# %%
twitterAPI.getTweets('Hillary Clinton')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-917afa0b60ab> in <module>()
# ----> 1 twitterAPI.getTweets('Hillary Clinton')
#
# /home/carl/Workspace/spark-for-python-developers/chapter3-juggling-data/TwitterAPI.py in getTweets(self, q, max_res)
#     148         while True:
#     149             try:
# --> 150                 self.searchTwitter(q, max_res=1000)
#     151             except twitter.api.TwitterHTTPError as e:
#     152                 error_count = 0
#
# /home/carl/Workspace/spark-for-python-developers/chapter3-juggling-data/TwitterAPI.py in searchTwitter(self, q, max_res, **kwargs)
#      86             kwargs = dict(next_results)
#      87             self.logger.info('++++++++++++++++++++++ api.search.tweets(for: %i) %s ' % (i, kwargs))
# ---> 88             search_results = self.api.search.tweets(**kwargs)
# ...

# %%
twitterAPI.getTweets('Donald Trump')
# Out:
# ---------------------------------------------------------------------------
# URLError                                  Traceback (most recent call last)
# <ipython-input-4-6fd653cad46b> in <module>()
# ----> 1 twitterAPI.getTweets('Donald Trump')
#
# /home/carl/Workspace/spark-for-python-developers/chapter3-juggling-data/TwitterAPI.py in getTweets(self, q, max_res)
#     148         while True:
#     149             try:
# --> 150                 self.searchTwitter(q, max_res=1000)
#     151             except twitter.api.TwitterHTTPError as e:
#     152                 error_count = 0
#
# /home/carl/Workspace/spark-for-python-developers/chapter3-juggling-data/TwitterAPI.py in searchTwitter(self, q, max_res, **kwargs)
#      86             kwargs = dict(next_results)
#      87             self.logger.info('++++++++++++++++++++++ api.search.tweets(for: %i) %s ' % (i, kwargs))
# ---> 88             search_results = self.api.search.tweets(**kwargs)
# ...

# %%
twitterAPI.getTweets('Lady Gaga')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-9d5c3ea35c55> in <module>()
# ----> 1 twitterAPI.getTweets('Lady Gaga')
#
# /home/carl/Workspace/spark-for-python-developers/chapter3-juggling-data/TwitterAPI.py in getTweets(self, q, max_res)
#     148         while True:
#     149             try:
# --> 150                 self.searchTwitter(q, max_res=1000)
#     151             except twitter.api.TwitterHTTPError as e:
#     152                 error_count = 0
#
# /home/carl/Workspace/spark-for-python-developers/chapter3-juggling-data/TwitterAPI.py in searchTwitter(self, q, max_res, **kwargs)
#      86             kwargs = dict(next_results)
#      87             self.logger.info('++++++++++++++++++++++ api.search.tweets(for: %i) %s ' % (i, kwargs))
# ---> 88             search_results = self.api.search.tweets(**kwargs)
# ...

# %%
twitterAPI.getTweets('Justin Bieber')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-b991492b37ad> in <module>()
# ----> 1 twitterAPI.getTweets('Justin Bieber')
#
# /home/carl/Workspace/spark-for-python-developers/chapter3-juggling-data/TwitterAPI.py in getTweets(self, q, max_res)
#     148         while True:
#     149             try:
# --> 150                 self.searchTwitter(q, max_res=1000)
#     151             except twitter.api.TwitterHTTPError as e:
#     152                 error_count = 0
#
# /home/carl/Workspace/spark-for-python-developers/chapter3-juggling-data/TwitterAPI.py in searchTwitter(self, q, max_res, **kwargs)
#      86             kwargs = dict(next_results)
#      87             self.logger.info('++++++++++++++++++++++ api.search.tweets(for: %i) %s ' % (i, kwargs))
# ---> 88             search_results = self.api.search.tweets(**kwargs)
# ...

# %%
twitterAPI.getTweets('iPhone')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-6276238733c5> in <module>()
# ----> 1 twitterAPI.getTweets('iPhone')
#
# /home/carl/Workspace/spark-for-python-developers/chapter3-juggling-data/TwitterAPI.py in getTweets(self, q, max_res)
#     152                 error_count = 0
#     153                 wait_period = 1
# --> 154                 wait_period = handleError(e, wait_period)
#     155                 if wait_period is None:
#     156                     return
#
# /home/carl/Workspace/spark-for-python-developers/chapter3-juggling-data/TwitterAPI.py in handleError(e, wait_period, slepp_when_rate_limited)
#     132                     self.logger.error('error 429 * Retrying in 15 minutes * in getTweets: %s' % (e))
#     133                     sys.stderr.flush()
# --> 134                     time.sleep(60*15 + 5)
# ...

# %%
twitterAPI.getTweets('Swift')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-363f7792b139> in <module>()
# ----> 1 twitterAPI.getTweets('Swift')
#
# /home/carl/Workspace/spark-for-python-developers/chapter3-juggling-data/TwitterAPI.py in getTweets(self, q, max_res)
#     152                 error_count = 0
#     153                 wait_period = 1
# --> 154                 wait_period = handleError(e, wait_period)
#     155                 if wait_period is None:
#     156                     return
#
# /home/carl/Workspace/spark-for-python-developers/chapter3-juggling-data/TwitterAPI.py in handleError(e, wait_period, slepp_when_rate_limited)
#     132                     self.logger.error('error 429 * Retrying in 15 minutes * in getTweets: %s' % (e))
#     133                     sys.stderr.flush()
# --> 134                     time.sleep(60*15 + 5)
# ...

# %%
twitterAPI.getTweets('Django')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-3527e5be0920> in <module>()
# ----> 1 twitterAPI.getTweets('Django')
#
# /home/carl/Workspace/spark-for-python-developers/chapter3-juggling-data/TwitterAPI.pyc in getTweets(self, q, max_res)
#     148         while True:
#     149             try:
# --> 150                 self.searchTwitter(q, max_res=1000)
#     151             except twitter.api.TwitterHTTPError as e:
#     152                 error_count = 0
#
# /home/carl/Workspace/spark-for-python-developers/chapter3-juggling-data/TwitterAPI.pyc in searchTwitter(self, q, max_res, **kwargs)
#      86             kwargs = dict(next_results)
#      87             self.logger.info('++++++++++++++++++++++ api.search.tweets(for: %i) %s ' % (i, kwargs))
# ---> 88             search_results = self.api.search.tweets(**kwargs)
# ...

# %%
twitterAPI.getTweets('Apple')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-8a777f3c7b53> in <module>()
# ----> 1 twitterAPI.getTweets('Apple')
#
# /home/carl/Workspace/spark-for-python-developers/chapter3-juggling-data/TwitterAPI.pyc in getTweets(self, q, max_res)
#     148         while True:
#     149             try:
# --> 150                 self.searchTwitter(q, max_res=1000)
#     151             except twitter.api.TwitterHTTPError as e:
#     152                 error_count = 0
#
# /home/carl/Workspace/spark-for-python-developers/chapter3-juggling-data/TwitterAPI.pyc in searchTwitter(self, q, max_res, **kwargs)
#      86             kwargs = dict(next_results)
#      87             self.logger.info('++++++++++++++++++++++ api.search.tweets(for: %i) %s ' % (i, kwargs))
# ---> 88             search_results = self.api.search.tweets(**kwargs)
# ...

# %%
twitterAPI.getTweets('China')
